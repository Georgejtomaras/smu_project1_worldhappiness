# %%
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import seaborn as sns
from scipy import stats as st
import statsmodels.api as sm
from scipy.stats import linregress
from scipy.stats import ttest_ind
from sklearn.linear_model import LinearRegression
import numpy as np

pd.set_option("display.max_columns", None)

# %%
data2015 = "../Data/2015.csv"
data2016 = "../Data/2016.csv"
data2017 = "../Data/2017.csv"
data2018 = "../Data/2018.csv"
data2019 = "../Data/2019.csv"

df1 = pd.read_csv(data2015)
df2 = pd.read_csv(data2016)
df3 = pd.read_csv(data2017)
df4 = pd.read_csv(data2018)
df5 = pd.read_csv(data2019)
df1["Year"]=2015
df2["Year"]=2016
df3["Year"]=2017
df4["Year"]=2018
df5["Year"]=2019

data_frames = [df1, df2, df3, df4, df5]

# %%
df6 = pd.DataFrame(df2015)
df7 = df6.sort_values(by="Economy (GDP per Capita)", ascending=False)
df7.plot(kind="line", x='Happiness Score', y='Economy (GDP per Capita)', grid=True)
plt.xticks(rotation=90)
# Out:
# (array([7.25, 7.3 , 7.35, 7.4 , 7.45, 7.5 , 7.55, 7.6 , 7.65]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
df6 = pd.DataFrame(df2)
df7 = df6.sort_values(by="Economy (GDP per Capita)", ascending=False)
df7.plot(x='Country', y='Economy (GDP per Capita)', grid=True)
plt.xticks(rotation=90)
# Out:
# (array([-20.,   0.,  20.,  40.,  60.,  80., 100., 120., 140., 160., 180.]),
#  [Text(-20.0, 0, 'Sierra Leone'),
#   Text(0.0, 0, 'Qatar'),
#   Text(20.0, 0, 'Belgium'),
#   Text(40.0, 0, 'Portugal'),
#   Text(60.0, 0, 'Azerbaijan'),
#   Text(80.0, 0, 'Macedonia'),
#   Text(100.0, 0, 'Angola'),
#   Text(120.0, 0, 'Mauritania'),
#   Text(140.0, 0, 'Myanmar'),
#   Text(160.0, 0, ''),
#   Text(180.0, 0, '')])

# %%
df6 = pd.DataFrame(df3)
df7 = df6.sort_values(by="Economy..GDP.per.Capita.", ascending=False)
df7.plot(x='Country', y='Economy..GDP.per.Capita.', grid=True)
plt.xticks(rotation=90)
# Out:
# (array([-20.,   0.,  20.,  40.,  60.,  80., 100., 120., 140., 160., 180.]),
#  [Text(-20.0, 0, 'South Sudan'),
#   Text(0.0, 0, 'Qatar'),
#   Text(20.0, 0, 'Belgium'),
#   Text(40.0, 0, 'Lithuania'),
#   Text(60.0, 0, 'Azerbaijan'),
#   Text(80.0, 0, 'Mongolia'),
#   Text(100.0, 0, 'Guatemala'),
#   Text(120.0, 0, 'Cambodia'),
#   Text(140.0, 0, 'Sierra Leone'),
#   Text(160.0, 0, ''),
#   Text(180.0, 0, '')])

# %%
df6 = pd.DataFrame(df4)
df7 = df6.sort_values(by="GDP per capita", ascending=False)
df7.plot(x='Country or region', y='GDP per capita', grid=True)
plt.xticks(rotation=90)
# Out:
# (array([-20.,   0.,  20.,  40.,  60.,  80., 100., 120., 140., 160., 180.]),
#  [Text(-20.0, 0, 'Zimbabwe'),
#   Text(0.0, 0, 'United Arab Emirates'),
#   Text(20.0, 0, 'Canada'),
#   Text(40.0, 0, 'Portugal'),
#   Text(60.0, 0, 'Gabon'),
#   Text(80.0, 0, 'Sri Lanka'),
#   Text(100.0, 0, 'Morocco'),
#   Text(120.0, 0, 'Mauritania'),
#   Text(140.0, 0, 'Afghanistan'),
#   Text(160.0, 0, ''),
#   Text(180.0, 0, '')])

# %%
df6 = pd.DataFrame(df5)
df7 = df6.sort_values(by="GDP per capita", ascending=False)
df7.plot(x='Country or region', y='GDP per capita', grid=True)
plt.xticks(rotation=90)
# Out:
# (array([-20.,   0.,  20.,  40.,  60.,  80., 100., 120., 140., 160., 180.]),
#  [Text(-20.0, 0, 'Chad'),
#   Text(0.0, 0, 'Qatar'),
#   Text(20.0, 0, 'Bahrain'),
#   Text(40.0, 0, 'Malaysia'),
#   Text(60.0, 0, 'Gabon'),
#   Text(80.0, 0, 'Sri Lanka'),
#   Text(100.0, 0, 'Guatemala'),
#   Text(120.0, 0, 'Ivory Coast'),
#   Text(140.0, 0, 'Haiti'),
#   Text(160.0, 0, ''),
#   Text(180.0, 0, '')])

# %%
box = pd.DataFrame(df1)
boxplot = box.boxplot(column=['Economy (GDP per Capita)', 'Happiness Score'], grid=True, figsize=(10, 6))

# %%
box = pd.DataFrame(df2)
boxplot = box.boxplot(column=['Economy (GDP per Capita)', 'Happiness Score'], grid=True, figsize=(10, 6))

# %%
box = pd.DataFrame(df3)
boxplot = box.boxplot(column=['Economy..GDP.per.Capita.', 'Happiness.Score'], grid=True, figsize=(10, 6))

# %%
box = pd.DataFrame(df4)
boxplot = box.boxplot(column=['GDP per capita', 'Score'], grid=True, figsize=(10, 6))

# %%
box = pd.DataFrame(df5)
boxplot = box.boxplot(column=['GDP per capita', 'Score'], grid=True, figsize=(10, 6))

# %%
avgdf.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 avgdf.head()
#
# NameError: name 'avgdf' is not defined

# %%
df1.quantile([.25, .50, .75])
# Out:
#       Happiness Rank  Happiness Score  Standard Error  \
# 0.25           40.25          4.52600        0.037268
# 0.50           79.50          5.23250        0.043940
# 0.75          118.75          6.24375        0.052300
#
#       Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 0.25                  0.545808  0.856823                  0.439185  0.328330
# 0.50                  0.910245  1.029510                  0.696705  0.435515
# 0.75                  1.158448  1.214405                  0.811013  0.549092
#
#       Trust (Government Corruption)  Generosity  Dystopia Residual    Year
# 0.25                       0.061675    0.150553           1.759410  2015.0
# 0.50                       0.107220    0.216130           2.095415  2015.0
# 0.75                       0.180255    0.309883           2.462415  2015.0

# %%
size_bins = [0, 0.545808, .91, 1.15, 1.7]
group_names = ["lowest", "lower average", "High average", "highest"]

# %%
avgdf["Economy Categorical"] = pd.cut(avgdf["Average Economy"], size_bins, labels=group_names, right=False)
avgdf
# Out:
#          Country  Average Economy  Average Happiness Score  \
# 0    Afghanistan         0.357113                  3.51280
# 1        Albania         0.938633                  4.71260
# 2        Algeria         1.012963                  5.66760
# 3         Angola         0.798380                  3.87225
# 4      Argentina         1.111035                  6.45940
# ..           ...              ...                      ...
# 165    Venezuela         1.052468                  5.53140
# 166      Vietnam         0.723416                  5.15460
# 167        Yemen         0.489313                  3.62580
# 168       Zambia         0.571761                  4.58440
# 169     Zimbabwe         0.344051                  4.00660
#
#     Economy categorical Economy Categorical
# 0                lowest              lowest
# 1          High average        High average
# 2          High average        High average
# 3         lower average       lower average
# ...

# %%
sns.violinplot(data=avgdf, x="Economy Categorical", y="Average Happiness Score", palette="rainbow_r")
plt.savefig("../george images")

# %%
maindf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 782 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Country                   782 non-null    object
#  1   Economy                   782 non-null    float64
#  2   Happiness_Score           782 non-null    float64
#  3   Happiness Rank            782 non-null    int64
#  4   Health (Life Expectancy)  782 non-null    float64
#  5   Generosity                782 non-null    float64
#  6   Social Support            782 non-null    float64
#  7   Freedom                   782 non-null    float64
#  8   Year                      782 non-null    int64
# dtypes: float64(6), int64(2), object(1)
# memory usage: 61.1+ KB

# %%
sns.violinplot(data=maindf, x="Year", y="Happiness_Score", palette="rainbow_r")
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Happiness_Score'>

# %%
sns.violinplot(data=maindf, x="Year", y="Economy", palette="rainbow_r")
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Economy'>

# %%
maindf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 782 entries, 0 to 155
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Country                   782 non-null    object
#  1   Economy                   782 non-null    float64
#  2   Happiness_Score           782 non-null    float64
#  3   Happiness Rank            782 non-null    int64
#  4   Health (Life Expectancy)  782 non-null    float64
#  5   Generosity                782 non-null    float64
#  6   Social Support            782 non-null    float64
#  7   Freedom                   782 non-null    float64
#  8   Year                      782 non-null    int64
# dtypes: float64(6), int64(2), object(1)
# memory usage: 61.1+ KB

# %%
size_bins = [0, 0.545808, .91, 1.15, 1.7]
group_names = ["lowest", "lower average", "High average", "highest"]

# %%
maindf["Economy Categorical"] = pd.cut(maindf["Economy"], size_bins, labels=group_names, right=False)

# %%
maindf.groupby("Economy Categorical")["Year"].value_counts().unstack().plot(kind="bar", subplots=True, figsize=(12, 12), layout=(2, 3), cmap="rainbow_r")
plt.show()

# %%
avgdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170 entries, 0 to 169
# Data columns (total 4 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Country                  170 non-null    object
#  1   Average Economy          170 non-null    float64
#  2   Average Happiness Score  170 non-null    float64
#  3   Economy categorical      169 non-null    category
# dtypes: category(1), float64(2), object(1)
# memory usage: 4.5+ KB

# %%
x = maindf[["Economy"]]
y = maindf[["Happiness_Score"]]
z = np.random.normal(0,1,782)

plt.scatter(x, y, c=z, cmap="hsv")
plt.xlabel("Economy")
plt.ylabel("Happiness Score")
plt.title("Economy vs Happiness Score")
# Out:
# Text(0.5, 1.0, 'Economy vs Happiness Score')

# %% [markdown]
#  Are larger, more developed countries happier?
#  Do happy people live longer?
#  Are certain regions happier?

# %%
maindf = pd.DataFrame()
maindf["Country"] = pd.concat([df1["Country"], df2["Country"], df3["Country"], df4["Country or region"], df5["Country or region"]])
maindf["Economy"] = pd.concat([df1["Economy (GDP per Capita)"], df2["Economy (GDP per Capita)"], df3["Economy..GDP.per.Capita."], df4["GDP per capita"], df5["GDP per capita"]])
maindf["Happiness_Score"] = pd.concat([df1["Happiness Score"], df2["Happiness Score"], df3["Happiness.Score"], df4["Score"], df5["Score"]])
maindf["Happiness Rank"] = pd.concat([df1["Happiness Rank"], df2["Happiness Rank"], df3["Happiness.Rank"], df4["Overall rank"], df5["Overall rank"]])
maindf["Health (Life Expectancy)"] = pd.concat([df1["Health (Life Expectancy)"], df2["Health (Life Expectancy)"], df3["Health..Life.Expectancy."], df4["Healthy life expectancy"], df5["Healthy life expectancy"]])
maindf["Generosity"] = pd.concat([df1["Generosity"], df2["Generosity"], df3["Generosity"], df4["Generosity"], df5["Generosity"]])
maindf["Social Support"] = pd.concat([df1["Family"], df2["Family"], df3["Family"], df4["Social support"], df5["Social support"]])
maindf["Freedom"] = pd.concat([df1["Freedom"], df2["Freedom"], df3["Freedom"], df4["Freedom to make life choices"], df5["Freedom to make life choices"]])
maindf["Year"] = pd.concat([df1["Year"], df2["Year"], df3["Year"], df4["Year"], df5["Year"]])
maindf.head(20)
# Out:
#                  Country  Economy  Happiness_Score  Happiness Rank  \
# 0            Switzerland  1.39651            7.587               1
# 1                Iceland  1.30232            7.561               2
# 2                Denmark  1.32548            7.527               3
# 3                 Norway  1.45900            7.522               4
# 4                 Canada  1.32629            7.427               5
# 5                Finland  1.29025            7.406               6
# 6            Netherlands  1.32944            7.378               7
# 7                 Sweden  1.33171            7.364               8
# 8            New Zealand  1.25018            7.286               9
# 9              Australia  1.33358            7.284              10
# 10                Israel  1.22857            7.278              11
# 11            Costa Rica  0.95578            7.226              12
# 12               Austria  1.33723            7.200              13
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        157 non-null    object
#  1   Region                         157 non-null    object
#  2   Happiness Rank                 157 non-null    int64
#  3   Happiness Score                157 non-null    float64
#  4   Lower Confidence Interval      157 non-null    float64
#  5   Upper Confidence Interval      157 non-null    float64
#  6   Economy (GDP per Capita)       157 non-null    float64
#  7   Family                         157 non-null    float64
#  8   Health (Life Expectancy)       157 non-null    float64
#  9   Freedom                        157 non-null    float64
#  10  Trust (Government Corruption)  157 non-null    float64
#  11  Generosity                     157 non-null    float64
# ...

# %%
avgdf = maindf.groupby('Country')[["Economy", "Happiness_Score"]].agg({"Economy": "mean", "Happiness_Score": "mean"}).reset_index()
avgdf["Economy categorical"] = pd.cut(avgdf["Economy"], size_bins, labels=group_names, right=False)
avgdf = avgdf.rename(columns={"Happiness_Score": "Average Happiness Score", "Economy": "Average Economy"})
avgdf
# Out:
#          Country  Average Economy  Average Happiness Score Economy categorical
# 0    Afghanistan         0.357113                  3.51280              lowest
# 1        Albania         0.938633                  4.71260        High average
# 2        Algeria         1.012963                  5.66760        High average
# 3         Angola         0.798380                  3.87225       lower average
# 4      Argentina         1.111035                  6.45940        High average
# ..           ...              ...                      ...                 ...
# 165    Venezuela         1.052468                  5.53140        High average
# 166      Vietnam         0.723416                  5.15460       lower average
# 167        Yemen         0.489313                  3.62580              lowest
# 168       Zambia         0.571761                  4.58440       lower average
# 169     Zimbabwe         0.344051                  4.00660              lowest
#
# [170 rows x 4 columns]

# %%
mask2016 = (df2["Happiness Rank"]<=10) & (df2["Year"]==2016)
df2016 = df2.loc[mask2016].reset_index(drop=True)
df2016
# Out:
#        Country                     Region  Happiness Rank  Happiness Score  \
# 0      Denmark             Western Europe               1            7.526
# 1  Switzerland             Western Europe               2            7.509
# 2      Iceland             Western Europe               3            7.501
# 3       Norway             Western Europe               4            7.498
# 4      Finland             Western Europe               5            7.413
# 5       Canada              North America               6            7.404
# 6  Netherlands             Western Europe               7            7.339
# 7  New Zealand  Australia and New Zealand               8            7.334
# 8    Australia  Australia and New Zealand               9            7.313
# 9       Sweden             Western Europe              10            7.291
#
#    Lower Confidence Interval  Upper Confidence Interval  \
# 0                      7.460                      7.592
# ...

# %%
mask2015 = (df1["Happiness Rank"]<=10) & (df1["Year"]==2015)
df2015 = df1.loc[mask2015].reset_index(drop=True)
df2015
# Out:
#        Country                     Region  Happiness Rank  Happiness Score  \
# 0  Switzerland             Western Europe               1            7.587
# 1      Iceland             Western Europe               2            7.561
# 2      Denmark             Western Europe               3            7.527
# 3       Norway             Western Europe               4            7.522
# 4       Canada              North America               5            7.427
# 5      Finland             Western Europe               6            7.406
# 6  Netherlands             Western Europe               7            7.378
# 7       Sweden             Western Europe               8            7.364
# 8  New Zealand  Australia and New Zealand               9            7.286
# 9    Australia  Australia and New Zealand              10            7.284
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# ...

# %%
sns.scatterplot(x='Happiness Score', y='Health (Life Expectancy)',palette= 'rainbow_r', data=df2015,hue='Happiness Score').set(title='Healthy life expectancy vs. Happiness Score 2015')
# Out:
# [Text(0.5, 1.0, 'Healthy life expectancy vs. Happiness Score 2015')]

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 10 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     156 non-null    float64
#  9   Year                          156 non-null    int64
# dtypes: float64(7), int64(2), object(1)
# memory usage: 12.3+ KB

# %%
mask2019 = (df5["Overall rank"]<=10) & (df5["Year"]==2019)
df2019 = df5.loc[mask2016].reset_index(drop=True)
df2019
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
# 5             6       Switzerland  7.480           1.452           1.526
# 6             7            Sweden  7.343           1.387           1.487
# 7             8       New Zealand  7.307           1.303           1.557
# 8             9            Canada  7.278           1.365           1.505
# 9            10           Austria  7.246           1.376           1.475
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# ...

# %%
st.ttest_ind(df2016["Happiness Score"], df2019["Score"], equal_var=False)
# Out:
# Ttest_indResult(statistic=-0.7276658661569179, pvalue=0.4788025567726826)

# %%
x = avgdf["Average Happiness Score"]
y = avgdf["Average Economy"]

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
z = np.random.normal(0,1,170)
plt.figure(figsize=(10,6))
plt.scatter(x, y, c=z, cmap="hsv")
plt.plot(x,regress_values,"r-", color="red", alpha= 1)
plt.title("Happiness Score vs Economy")
plt.xlabel("Average Happiness Score")
plt.ylabel("Average Economy")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# y = 0.3x + -0.7
# C:\Users\George\AppData\Local\Temp\ipykernel_10588\1043466755.py:11: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(x,regress_values,"r-", color="red", alpha= 1)
# The r-squared is: 0.6454995141242952

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 10 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     156 non-null    float64
#  9   Year                          156 non-null    int64
# dtypes: float64(7), int64(2), object(1)
# memory usage: 12.3+ KB

# %%
x = df5["Score"]
y = df5["GDP per capita"]

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
z = np.random.normal(0,1,156)
plt.figure(figsize=(10,6))
plt.scatter(x, y, c=z, cmap="hsv")
plt.plot(x,regress_values,"r-", color="red", alpha= 1)
plt.title("Happiness Score vs Economy 2019")
plt.xlabel("Happiness Score")
plt.ylabel("Economy (GDP per Capita)")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# y = 0.28x + -0.63
# The r-squared is: 0.6302500079104004
# C:\Users\George\AppData\Local\Temp\ipykernel_10588\3081169344.py:11: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(x,regress_values,"r-", color="red", alpha= 1)

# %%
x = df4["Score"]
y = df4["GDP per capita"]

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
z = np.random.normal(0,1,156)
plt.figure(figsize=(10,6))
plt.scatter(x, y, c=z, cmap="hsv")
plt.plot(x,regress_values,"r-", color="red", alpha= 1)
plt.title("Happiness Score vs Economy 2018")
plt.xlabel("Happiness Score")
plt.ylabel("Economy (GDP per Capita)")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# y = 0.28x + -0.62
# C:\Users\George\AppData\Local\Temp\ipykernel_10588\2443340122.py:11: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(x,regress_values,"r-", color="red", alpha= 1)
# The r-squared is: 0.6434028259180178

# %%
x = df3["Happiness.Score"]
y = df3["Economy..GDP.per.Capita."]

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
z = np.random.normal(0,1,155)
plt.figure(figsize=(10,6))
plt.scatter(x, y, c=z, cmap="hsv")
plt.plot(x,regress_values,"r-", color="red", alpha= 1)
plt.title("Happiness Score vs Economy 2017")
plt.xlabel("Happiness Score")
plt.ylabel("Economy (GDP per Capita)")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# y = 0.3x + -0.63
# The r-squared is: 0.6601054760421117
# C:\Users\George\AppData\Local\Temp\ipykernel_10588\3081936296.py:11: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(x,regress_values,"r-", color="red", alpha= 1)

# %%
x = df2["Happiness Score"]
y = df2["Economy (GDP per Capita)"]

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
z = np.random.normal(0,1,157)
plt.figure(figsize=(10,6))
plt.scatter(x, y, c=z, cmap="hsv")
plt.plot(x,regress_values,"r-", color="red", alpha= 1)
plt.title("Happiness Score vs Economy 2016")
plt.xlabel("Happiness Score")
plt.ylabel("Economy (GDP per Capita)")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# y = 0.29x + -0.58
# The r-squared is: 0.6246088901220198
# C:\Users\George\AppData\Local\Temp\ipykernel_10588\157965477.py:11: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(x,regress_values,"r-", color="red", alpha= 1)

# %%
x = df1["Happiness Score"]
y = df1["Economy (GDP per Capita)"]

(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x, y)
regress_values = x * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(line_eq)
z = np.random.normal(0,1,158)
plt.figure(figsize=(10,6))
plt.scatter(x, y, c=z, cmap="hsv")
plt.plot(x,regress_values,"r-", color="red", alpha= 1)
plt.title("Happiness Score vs Economy 2015")
plt.xlabel("Happiness Score")
plt.ylabel("Economy (GDP per Capita)")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# y = 0.27x + -0.63
# C:\Users\George\AppData\Local\Temp\ipykernel_10588\1875863227.py:11: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "r-" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(x,regress_values,"r-", color="red", alpha= 1)
# The r-squared is: 0.6099071541531222

# %%
sns.violinplot(data=avgdf, x="Economy categorical", y="Average Happiness Score")
# Out:
# <AxesSubplot:xlabel='Economy categorical', ylabel='Average Happiness Score'>

# %%
maindf.groupby("Year")[["Country", "Happiness Rank"]].apply(lambda x: x.sort_values('Happiness Rank'))
# Out:
#                       Country  Happiness Rank
# 0                 Switzerland               1
# 1                     Iceland               2
# 2                     Denmark               3
# 3                      Norway               4
# 4                      Canada               5
# ..                        ...             ...
# 151                    Rwanda             152
# 152                  Tanzania             153
# 153               Afghanistan             154
# 154  Central African Republic             155
# 155               South Sudan             156
#
# [782 rows x 2 columns]

# %%
"""
line chart for top 5 and bottom 5 

"""
# Out:
# '\nline chart for top 5 and bottom 5 \n\n'

# %%
x1_value = df5["GDP per capita"]
y1_value = df5["Score"]

# %%
X = sm.add_constant(x1_value)
Y = y1_value
model = sm.OLS(Y, X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Score   R-squared:                       0.630
# Model:                            OLS   Adj. R-squared:                  0.628
# Method:                 Least Squares   F-statistic:                     262.5
# Date:                Sun, 13 Nov 2022   Prob (F-statistic):           4.32e-35
# Time:                        21:18:35   Log-Likelihood:                -159.97
# No. Observations:                 156   AIC:                             323.9
# Df Residuals:                     154   BIC:                             330.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
predictions = results.predict()
resids = y1_value - predictions
print(resids)
# Out:
# 0      1.397337
# 1      1.132956
# 2      0.854051
# 3      1.033611
# 4      0.992120
#          ...
# 151   -0.861660
# 152   -1.224184
# 153   -0.972697
# 154   -0.374017
# 155   -1.225098
# Name: Score, Length: 156, dtype: float64

# %%
z = np.random.normal(0,1,156)
plt.scatter(y1_value, predictions, c=z, cmap="hsv")
plt.plot(y1_value, y1_value, color="red")
plt.title("Actual vs Predictions")
plt.xlabel("Economy (GDP per Capita)")
plt.ylabel("Happiness Score")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 10 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     156 non-null    float64
#  9   Year                          156 non-null    int64
# dtypes: float64(7), int64(2), object(1)
# memory usage: 12.3+ KB

# %%
"""
Use the groupby to group by year, then aggregate by average of gpd and happiness rank
A) Are larger more developed countries more happy? 
"""
# Out:
# '\nUse the groupby to group by year, then aggregate by average of gpd and happiness rank\nA) Are larger more developed countries more happy? \n'

# %%
sns.barplot(x='Health (Life Expectancy)',y='Country',data=df1.nlargest(10,'Health (Life Expectancy)'),palette="rainbow_r", title="")
# Out:
# <AxesSubplot:xlabel='Health (Life Expectancy)', ylabel='Country'>

# %%
sns.barplot(x='Economy (GDP per Capita)',y='Country',data=df1.nlargest(10,'Economy (GDP per Capita)'),palette="rainbow_r").set(title='Top 10 Countries Based on GDP for 2015')
# Out:
# [Text(0.5, 1.0, 'Top 10 Countries Based on GDP for 2015')]

# %%
sns.barplot(x='Happiness Score' ,y='Country',data=avgdf.nlargest(10,'Happiness Score'),palette='rainbow_r')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Happiness Score'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
sns.barplot(x='Economy (GDP per Capita)' ,y='Country',data=df2.nlargest(10,'Economy (GDP per Capita)'),palette='rainbow_r').set(title='Top 10 Countries Based on GDP for 2016')
# Out:
# [Text(0.5, 1.0, 'Top 10 Countries Based on GDP for 2016')]

# %%
sns.barplot(x='Happiness Score' ,y='Country',data=df2.nlargest(10,'Happiness Score'),palette='rainbow_r')

# %%
sns.barplot(x='Economy..GDP.per.Capita.' ,y='Country',data=df3.nlargest(10,'Economy..GDP.per.Capita.'),palette='rainbow_r').set(title='Top 10 Countries Based on GDP for 2017')
# Out:
# [Text(0.5, 1.0, 'Top 10 Countries Based on GDP for 2017')]

# %%
sns.barplot(x='Happiness.Score' ,y='Country',data=df3.nlargest(10,'Happiness.Score'),palette='rainbow_r')

# %%
sns.barplot(x='GDP per capita' ,y='Country or region',data=df4.nlargest(10,'GDP per capita'),palette='rainbow_r').set(title='Top 10 Countries Based on GDP for 2018')
# Out:
# [Text(0.5, 1.0, 'Top 10 Countries Based on GDP for 2018')]

# %%
sns.barplot(x='Score' ,y='Country or region',data=df4.nlargest(10,'Score'),palette='rainbow_r')

# %%
sns.barplot(x='GDP per capita' ,y='Country or region',data=df5.nlargest(10,'GDP per capita'),palette='rainbow_r').set(title='Top 10 Countries Based on GDP for 2019')
# Out:
# [Text(0.5, 1.0, 'Top 10 Countries Based on GDP for 2019')]

# %%
sns.barplot(x='Score' ,y='Country or region',data=df5.nlargest(10,'Score'),palette='rainbow_r')

# %%
x = df1[["Economy (GDP per Capita)"]]
y = df1[["Happiness Score"]]
colors = ()

plt.scatter(x, y)
plt.xlabel("Economy")
plt.ylabel("Happiness Score")
plt.title("2015 Economy vs Happiness Score")
# Out:
# Text(0.5, 1.0, '2015 Economy vs Happiness Score')

# %%
x = df2[["Economy (GDP per Capita)"]]
y = df2[["Happiness Score"]]
colors = ()

plt.scatter(x, y)
plt.xlabel("Economy")
plt.ylabel("Happiness Score")
plt.title("2016 Economy vs Happiness Score")
# Out:
# Text(0.5, 1.0, '2016 Economy vs Happiness Score')

# %%
x = df3[["Economy..GDP.per.Capita."]]
y = df3[["Happiness.Score"]]
colors = ()

plt.scatter(x, y)
plt.xlabel("Economy")
plt.ylabel("Happiness Score")
plt.title("2017 Economy vs Happiness Score")
# Out:
# Text(0.5, 1.0, '2017 Economy vs Happiness Score')

# %%
x = df4[["GDP per capita"]]
y = df4[["Score"]]
colors = ()

plt.scatter(x, y)
plt.xlabel("Economy")
plt.ylabel("Happiness Score")
plt.title("2018 Economy vs Happiness Score")
# Out:
# Text(0.5, 1.0, '2018 Economy vs Happiness Score')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
maindf.groupby("Year").plot.scatter(x="Economy", y="Happiness_Score")
# Out:
# Year
# 2015    AxesSubplot(0.125,0.125;0.775x0.755)
# 2016    AxesSubplot(0.125,0.125;0.775x0.755)
# 2017    AxesSubplot(0.125,0.125;0.775x0.755)
# 2018    AxesSubplot(0.125,0.125;0.775x0.755)
# 2019    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 10 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  156 non-null    int64
#  1   Country or region             156 non-null    object
#  2   Score                         156 non-null    float64
#  3   GDP per capita                156 non-null    float64
#  4   Social support                156 non-null    float64
#  5   Healthy life expectancy       156 non-null    float64
#  6   Freedom to make life choices  156 non-null    float64
#  7   Generosity                    156 non-null    float64
#  8   Perceptions of corruption     156 non-null    float64
#  9   Year                          156 non-null    int64
# dtypes: float64(7), int64(2), object(1)
# memory usage: 12.3+ KB

# %%
"""
For question:  Are larger, more developed countries happier?, we want to select Economy GDP per Capita, Country, Region, 
Happiness Score, Happiness Rank, 
"""
# Out:
# '\nFor question:  Are larger, more developed countries happier?, we want to select Economy GDP per Capita, Country, Region, \nHappiness Score, Happiness Rank, \n'

# %%
"""
Use the groupby to group by year, then aggregate by average of gpd and happiness rank

"""
# Out:
# '\nUse the groupby to group by year, then aggregate by average of gpd and happiness rank\n\n'

# %%
for i in data_frames:
    print(i.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
for i in data_frames:
    print(i.head())
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
maindf2 = maindf.reset_index(drop=True)

# %%
import seaborn as sns
from scipy import stats as st

# linear modelling
import statsmodels.api as sm
from scipy.stats import linregress
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

# %%
def checkShapeOfData(df, col):
    # make histogram plot
    plt.figure(figsize=(10,6))
    sns.histplot(data=df, x=col, color="cyan", kde=True)
    plt.title(f"HistPlot of {col}")
    plt.show()
    print()
    
    # boxplots
    plt.figure(figsize=(10,6))
    sns.boxplot(data=df, y=col, palette="rainbow_r")
    plt.title(f"Boxplot of {col}")
    plt.show()
    print()
    
    # If the data is in a dataframe, we use pandas to give quartile calculations
    quartiles = df[col].quantile([.25,.5,.75])
    lowerq = quartiles[0.25]
    upperq = quartiles[0.75]
    iqr = upperq-lowerq
    
    lower_bound = lowerq - (1.5*iqr)
    upper_bound = upperq + (1.5*iqr)
    print(f"Values below {lower_bound} could be outliers.")
    print(f"Values above {upper_bound} could be outliers.")
    
    # normaltest
    print()
    print("Normal test:")
    num = int(len(df)*0.1)
#     print(st.normaltest(df[col].sample(num)))

# %%
cols = maindf2.describe().columns
for col in cols:
    checkShapeOfData(maindf2, col)
    plt.savefig("../regression")
# Out:
# Values below -0.3380306634902951 could be outliers.
# Values above 2.1807177724838254 could be outliers.
#
# Normal test:
# Values below 1.990125 could be outliers.
# Values above 8.709125 could be outliers.
#
# Normal test:
# Values below -77.0 could be outliers.
# Values above 235.0 could be outliers.
#
# Normal test:
# Values below -0.11154374999999994 could be outliers.
# Values above 1.35972625 could be outliers.
#
# Normal test:
# Values below -0.09324874999999996 could be outliers.
# Values above 0.5020812499999999 could be outliers.
#
# Normal test:
# Values below 0.18253125000000003 could be outliers.
# Values above 2.0140812500000003 could be outliers.
#
# Normal test:
# Values below -0.022081249999999997 could be outliers.
# Values above 0.86284875 could be outliers.
#
# Normal test:

# %%
maindf2.corr()
# Out:
#                            Economy  Happiness_Score  Happiness Rank  \
# Economy                   1.000000         0.789284       -0.794791
# Happiness_Score           0.789284         1.000000       -0.992066
# Happiness Rank           -0.794791        -0.992066        1.000000
# Health (Life Expectancy)  0.784338         0.742456       -0.743655
# Generosity               -0.014560         0.137578       -0.117713
# Social Support            0.585966         0.648799       -0.644842
# Freedom                   0.340511         0.551258       -0.537942
# Year                      0.019768         0.007065       -0.007768
#
#                           Health (Life Expectancy)  Generosity  \
# Economy                                   0.784338   -0.014560
# Happiness_Score                           0.742456    0.137578
# Happiness Rank                           -0.743655   -0.117713
# Health (Life Expectancy)                  1.000000    0.010638
# ...

# %%
 corrs = maindf2.corr()

plt.figure(figsize=(10,6))
sns.heatmap(corrs, cmap="rainbow_r")
plt.title("Correlation Heatmap")
plt.show()
plt.savefig("../heatmap")

# %%
feature1 = maindf2.loc[:,["Happiness_Score"]]
target1 = maindf2["Economy"]

# %%
  # STATSMODELS
X1 = sm.add_constant(feature1)
Y1 = target1

model = sm.OLS(Y1,X1)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                Economy   R-squared:                       0.623
# Model:                            OLS   Adj. R-squared:                  0.622
# Method:                 Least Squares   F-statistic:                     1289.
# Date:                Sun, 13 Nov 2022   Prob (F-statistic):          2.21e-167
# Time:                        21:24:56   Log-Likelihood:                -25.398
# No. Observations:                 782   AIC:                             54.80
# Df Residuals:                     780   BIC:                             64.12
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
feature = maindf2.loc[:,["Economy", "Health (Life Expectancy)", "Generosity", "Social Support", "Freedom"]]
target = maindf2["Happiness_Score"]

# %%
  # STATSMODELS
X = sm.add_constant(feature)
Y = target

model = sm.OLS(Y,X)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:        Happiness_Score   R-squared:                       0.760
# Model:                            OLS   Adj. R-squared:                  0.758
# Method:                 Least Squares   F-statistic:                     490.4
# Date:                Sun, 13 Nov 2022   Prob (F-statistic):          2.48e-237
# Time:                        21:25:01   Log-Likelihood:                -645.59
# No. Observations:                 782   AIC:                             1303.
# Df Residuals:                     776   BIC:                             1331.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# ...

# %%
maindf2.head()
# Out:
#        Country  Economy  Happiness_Score  Happiness Rank  \
# 0  Switzerland  1.39651            7.587               1
# 1      Iceland  1.30232            7.561               2
# 2      Denmark  1.32548            7.527               3
# 3       Norway  1.45900            7.522               4
# 4       Canada  1.32629            7.427               5
#
#    Health (Life Expectancy)  Generosity  Social Support  Freedom  Year  \
# 0                   0.94143     0.29678         1.34951  0.66557  2015
# 1                   0.94784     0.43630         1.40223  0.62877  2015
# 2                   0.87464     0.34139         1.36058  0.64938  2015
# 3                   0.88521     0.34699         1.33095  0.66973  2015
# 4                   0.90563     0.45811         1.32261  0.63297  2015
#
#   Economy Categorical
# 0             highest
# 1             highest
# 2             highest
# 3             highest
# 4             highest

# %%
 # SCIKIT_LEARN

reg = LinearRegression()
reg.fit(np.array(feature), np.array(target))
print(reg.coef_)
print(reg.intercept_)
print(reg.score(np.array(feature), np.array(target)))
# Out:
# [1.21132866 1.00527655 0.74421236 0.58623713 1.70572833]
# 2.1576664897801443
# 0.7595880117729487

# %%
z = np.random.normal(0,1,782)
plt.scatter(target, reg.predict(np.array(feature)), c=z, cmap="hsv")
plt.plot(target, target)
plt.xlabel("Happiness Score")
plt.ylabel("Economy (GDP)")
plt.savefig("../george images")
plt.show()

# %%
rf = RandomForestRegressor()
rf.fit(np.array(feature), np.array(target))
print(rf.score(np.array(feature), np.array(target)))
# Out:
# 0.9727825140364601

# %%
rf = RandomForestRegressor()
rf.fit(np.array(feature1), np.array(target1))
print(rf.score(np.array(feature1), np.array(target1)))
# Out:
# 0.9076987755990588

# %%
z = np.random.normal(0,1,782)
plt.scatter(target1, rf.predict(np.array(feature1)), c=z, cmap="hsv")
plt.plot(target1, target1)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("Happiness Score: Prediction vs Actual")
plt.savefig("../george images")
plt.show()

# %%
z = np.random.normal(0,1,782)
plt.scatter(target, rf.predict(np.array(feature)), c=z, cmap="hsv")
plt.plot(target, target)
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.savefig("../george images")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [119], in <cell line: 2>()
#       1 z = np.random.normal(0,1,782)
# ----> 2 plt.scatter(target, rf.predict(np.array(feature)), c=z, cmap="hsv")
#       3 plt.plot(target, target)
#       4 plt.xlabel("Actual")
#
# File ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:971, in ForestRegressor.predict(self, X)
#     969 check_is_fitted(self)
#     970 # Check data
# --> 971 X = self._validate_X_predict(X)
#     973 # Assign chunk of trees to jobs
#     974 n_jobs, _, _ = _partition_estimators(self.n_estimators, self.n_jobs)
#
# File ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py:579, in BaseForest._validate_X_predict(self, X)
#     576 """
#     577 Validate X whenever one tries to predict, apply, predict_proba."""
#     578 check_is_fitted(self)
# ...

# %%
data = feature.iloc[0]
data
# Out:
# Economy                     1.39651
# Health (Life Expectancy)    0.94143
# Generosity                  0.29678
# Social Support              1.34951
# Freedom                     0.66557
# Name: 0, dtype: float64

# %%
maindf2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 782 entries, 0 to 781
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Country                   782 non-null    object
#  1   Economy                   782 non-null    float64
#  2   Happiness_Score           782 non-null    float64
#  3   Happiness Rank            782 non-null    int64
#  4   Health (Life Expectancy)  782 non-null    float64
#  5   Generosity                782 non-null    float64
#  6   Social Support            782 non-null    float64
#  7   Freedom                   782 non-null    float64
#  8   Year                      782 non-null    int64
#  9   Economy Categorical       778 non-null    category
# dtypes: category(1), float64(6), int64(2), object(1)
# memory usage: 56.1+ KB

# %%
data["Economy"]=2.0
data["Health (Life Expectancy)"]=1.0
data["Generosity"]=1.5
data["Social Support"]=1.5
data["Freedom"]=1.1

rf.predict([data])
# Out:
# array([6.95078999])

# %%
reg.predict([data])
# Out:
# array([6.9429784])

# %%
maindf2.loc[maindf2.Country=="Iran"]
# Out:
#     Country   Economy  Happiness_Score  Happiness Rank  \
# 109    Iran  1.008800            4.686             110
# 262    Iran  1.117580            4.813             105
# 422    Iran  1.156873            4.692             108
# 575    Iran  1.059000            4.707             106
# 742    Iran  1.100000            4.548             117
#
#      Health (Life Expectancy)  Generosity  Social Support   Freedom  Year  \
# 109                  0.698050    0.380860        0.544470  0.300330  2015
# 262                  0.642320    0.385380        0.388570  0.225440  2016
# 422                  0.639333    0.387243        0.711551  0.249323  2017
# 575                  0.691000    0.282000        0.771000  0.459000  2018
# 742                  0.785000    0.270000        0.842000  0.305000  2019
#
#     Economy Categorical
# 109        High average
# 262        High average
# 422             highest
# 575        High average
# 742        High average

# %%
data1 = feature.iloc[742]
data1
# Out:
# Economy                     1.100
# Health (Life Expectancy)    0.785
# Generosity                  0.270
# Social Support              0.842
# Freedom                     0.305
# Name: 742, dtype: float64

# %%
data1["Social Support"]=1.2
data1["Generosity"]=.8
rf.predict([data1])
# Out:
# array([4.93552001])
